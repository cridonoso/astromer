# %%
cd ../
# Out:
# /home/users/dmoreno2016

# %%
import pandas as pd

from codes_implemented.utils import open_subsets

# %load_ext autoreload
# %autoreload 2
# Out:
# 2023-09-18 15:57:19.640086: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Dataset alcock
path_subset_train = f'data/records/alcock/fold_0/alcock/train'
path_subset_val = f'data/records/alcock/fold_0/alcock/val'
path_subset_test = f'data/records/alcock/fold_0/alcock/test'

train_alcock, val_alcock, test_alcock = open_subsets(path_subset_train, 
                                                     path_subset_val, 
                                                     path_subset_test)

############################################################################################

# Dataset alcock-ATLAS
path_subset_train = f'data/records/alcock_atlas_linear/fold_0/alcock_atlas_linear/train'
path_subset_val = f'data/records/alcock_atlas_linear/fold_0/alcock_atlas_linear/val'
path_subset_test = f'data/records/alcock_atlas_linear/fold_0/alcock_atlas_linear/test'


train_alcock_atlas_linear, val_alcock_atlas_linear, test_alcock_atlas_linear = open_subsets(path_subset_train, 
                                                                       path_subset_val, 
                                                                       path_subset_test)

# Dataset alcock-OGLE
path_subset_train = f'data/records/alcock_ogle_linear/fold_0/alcock_ogle_linear/train'
path_subset_val = f'data/records/alcock_ogle_linear/fold_0/alcock_ogle_linear/val'
path_subset_test = f'data/records/alcock_ogle_linear/fold_0/alcock_ogle_linear/test'


train_alcock_ogle_linear, val_alcock_ogle_linear, test_alcock_ogle_linear = open_subsets(path_subset_train, 
                                                                       path_subset_val, 
                                                                       path_subset_test)

############################################################################################

# Dataset alcock-ATLAS
path_subset_train = f'data/records/alcock_atlas_cubic/fold_0/alcock_atlas_cubic/train'
path_subset_val = f'data/records/alcock_atlas_cubic/fold_0/alcock_atlas_cubic/val'
path_subset_test = f'data/records/alcock_atlas_cubic/fold_0/alcock_atlas_cubic/test'


train_alcock_atlas_cubic, val_alcock_atlas_cubic, test_alcock_atlas_cubic = open_subsets(path_subset_train, 
                                                                       path_subset_val, 
                                                                       path_subset_test)

# Dataset alcock-OGLE
path_subset_train = f'data/records/alcock_ogle_cubic/fold_0/alcock_ogle_cubic/train'
path_subset_val = f'data/records/alcock_ogle_cubic/fold_0/alcock_ogle_cubic/val'
path_subset_test = f'data/records/alcock_ogle_cubic/fold_0/alcock_ogle_cubic/test'


train_alcock_ogle_cubic, val_alcock_ogle_cubic, test_alcock_ogle_cubic = open_subsets(path_subset_train, 
                                                                       path_subset_val, 
                                                                       path_subset_test)
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dict_classes = {'D': 0, 'SD': 1, 'OC': 2, 'ELV': 3}
dict_classes
# Out:
# {'D': 0, 'SD': 1, 'OC': 2, 'ELV': 3}

# %%
fs = 20
columns = 1
rows = 4

ids_row = np.random.choice(list(train_kepler.keys()), 1)[0]
ids_row = b'05653152'
print('ID: {}'.format(ids_row))
#np_sample_ids = sample_ids.reshape(rows, columns)

fig, axes = plt.subplots(rows, columns, figsize=(15, 10), squeeze=False, sharex=True)

np_lc = train_kepler[ids_row].numpy()
min_mjd = np.min(train_kepler[ids_row].numpy()[:,0])
max_mjd = np.max(train_kepler[ids_row].numpy()[:,0])

min_flux = np.min(train_kepler[ids_row].numpy()[:,1])
max_flux = np.max(train_kepler[ids_row].numpy()[:,1])

axes[0, 0].set_title('KEPLER - Num_obs: {}'.format(len(np_lc)), size=fs)
axes[0, 0].plot(np_lc[:,0], np_lc[:,1], linewidth=1)
axes[0, 0].scatter(np_lc[:,0], np_lc[:,1], s=0.5)
axes[0, 0].tick_params(axis='both', which='major', labelsize=fs)
axes[0, 0].set_ylim(min_flux - 0.05, max_flux + 0.05)
axes[0, 0].set_xlim(min_mjd - 10, max_mjd + 10)


np_lc = train_kepler_alcock_linear[ids_row].numpy()
#np_lc_filtered = np_lc[np_lc[:,0] < max_mjd]
axes[1, 0].set_title('KEPLER with ALCOCK cadence - Num_obs: {}'.format(len(np_lc)), size=fs)
axes[1, 0].plot(np_lc[:,0], np_lc[:,1], linewidth=1)
axes[1, 0].scatter(np_lc[:,0], np_lc[:,1], s=4)
axes[1, 0].tick_params(axis='both', which='major', labelsize=fs)
axes[1, 0].set_ylim(min_flux - 0.05, max_flux + 0.05)
axes[1, 0].set_xlim(min_mjd - 10, max_mjd + 10)

np_lc = train_kepler_ogle_linear[ids_row].numpy()
#np_lc_filtered = np_lc[np_lc[:,0] < max_mjd]
axes[2, 0].set_title('KEPLER with OGLE cadence - Num_obs: {}'.format(len(np_lc)), size=fs)
axes[2, 0].plot(np_lc[:,0], np_lc[:,1], linewidth=1)
axes[2, 0].scatter(np_lc[:,0], np_lc[:,1], s=4)
axes[2, 0].tick_params(axis='both', which='major', labelsize=fs)
axes[2, 0].set_ylim(min_flux - 0.05, max_flux + 0.05)
axes[2, 0].set_xlim(min_mjd - 10, max_mjd + 10)

np_lc = train_kepler_atlas_linear[ids_row].numpy()
#np_lc_filtered = np_lc[np_lc[:,0] < max_mjd]
axes[3, 0].set_title('KEPLER with ATLAS cadence - Num_obs: {}'.format(len(np_lc)), size=fs)
axes[3, 0].plot(np_lc[:,0], np_lc[:,1], linewidth=1)
axes[3, 0].scatter(np_lc[:,0], np_lc[:,1], s=4)
axes[3, 0].tick_params(axis='both', which='major', labelsize=fs)
axes[3, 0].set_ylim(min_flux - 0.05, max_flux + 0.05)
axes[3, 0].set_xlim(min_mjd - 10, max_mjd + 10)
    
plt.tight_layout()
plt.show()
# Out:
# ID: b'05653152'
