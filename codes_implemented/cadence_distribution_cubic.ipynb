# %%
cd ../
# Out:
# /home/users/dmoreno2016

# %%
import os
import seaborn as sns

import tensorflow as tf
tf.get_logger().setLevel('INFO')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from codes_implemented.utils import open_subsets, distribution_values, create_df_dataset

# %load_ext autoreload
# %autoreload 2

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
# Out:
# 2023-09-18 15:55:46.473167: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
### ------------------------------------------------------------------------ ###

# Dataset ALCOCK
path_subset_train_alcock = f'data/records/alcock/fold_0/alcock_500/train'
path_subset_val_alcock = f'data/records/alcock/fold_0/alcock_500/val'
path_subset_test_alcock = f'data/records/alcock/fold_0/alcock_500/test'

train_alcock, val_alcock, test_alcock = open_subsets(path_subset_train_alcock, 
                                                  path_subset_val_alcock, 
                                                  path_subset_test_alcock)


# Dataset ATLAS
path_subset_train_atlas = f'data/records/atlas/fold_0/atlas_500/train'
path_subset_val_atlas = f'data/records/atlas/fold_0/atlas_500/val'
path_subset_test_atlas = f'data/records/atlas/fold_0/atlas_500/test'

train_atlas, val_atlas, test_atlas = open_subsets(path_subset_train_atlas, 
                                                  path_subset_val_atlas, 
                                                  path_subset_test_atlas)

# Dataset OGLE
path_subset_train_ogle = f'data/records/ogle/fold_0/ogle_500/train'
path_subset_val_ogle = f'data/records/ogle/fold_0/ogle_500/val'
path_subset_test_ogle = f'data/records/ogle/fold_0/ogle_500/test'


train_ogle, val_ogle, test_ogle = open_subsets(path_subset_train_ogle, 
                                               path_subset_val_ogle, 
                                               path_subset_test_ogle)

### ------------------------------------------------------------------------ ###

## Dataset ALCOCK-ATLAS
#path_subset_train = f'data/records/alcock_atlas_cubic/fold_0/alcock_atlas_cubic_500/train'
#path_subset_val = f'data/records/alcock_atlas_cubic/fold_0/alcock_atlas_cubic_500/val'
#path_subset_test = f'data/records/alcock_atlas_cubic/fold_0/alcock_atlas_cubic_500/test'
#
#train_alcock_atlas_cubic, val_alcock_atlas_cubic, test_alcock_atlas_cubic = open_subsets(path_subset_train, 
#                                                                        path_subset_val, 
#                                                                        path_subset_test)
#
## Dataset ALCOCK-OGLE
#path_subset_train = f'data/records/alcock_ogle_cubic/fold_0/alcock_ogle_cubic_500/train'
#path_subset_val = f'data/records/alcock_ogle_cubic/fold_0/alcock_ogle_cubic_500/val'
#path_subset_test = f'data/records/alcock_ogle_cubic/fold_0/alcock_ogle_cubic_500/test'
#
#
#train_alcock_ogle_cubic, val_alcock_ogle_cubic, test_alcock_ogle_cubic = open_subsets(path_subset_train, 
#                                                                    path_subset_val, 
#                                                                    path_subset_test)

### ------------------------------------------------------------------------ ###

# Dataset KEPLER
path_subset_train = f'data/records/kepler/fold_0/kepler/train'
path_subset_val = f'data/records/kepler/fold_0/kepler/val'
path_subset_test = f'data/records/kepler/fold_0/kepler/test'

train_kepler, val_kepler, test_kepler = open_subsets(path_subset_train, 
                                                     path_subset_val, 
                                                     path_subset_test)

# Dataset KEPLER-ALCOCK
path_subset_train = f'data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/train'
path_subset_val = f'data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/val'
path_subset_test = f'data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/test'


train_kepler_alcock_cubic, val_kepler_alcock_cubic, test_kepler_alcock_cubic = open_subsets(path_subset_train, 
                                                                          path_subset_val, 
                                                                          path_subset_test)

# Dataset KEPLER-ATLAS
path_subset_train = f'data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/train'
path_subset_val = f'data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/val'
path_subset_test = f'data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/test'


train_kepler_atlas_cubic, val_kepler_atlas_cubic, test_kepler_atlas_cubic = open_subsets(path_subset_train, 
                                                                       path_subset_val, 
                                                                       path_subset_test)

# Dataset KEPLER-OGLE
path_subset_train = f'data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/train'
path_subset_val = f'data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/val'
path_subset_test = f'data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/test'


train_kepler_ogle_cubic, val_kepler_ogle_cubic, test_kepler_ogle_cubic = open_subsets(path_subset_train, 
                                                                    path_subset_val, 
                                                                    path_subset_test)
# Out:
# Number of records within a class: RRc
#  - opening: data/records/alcock/fold_0/alcock_500/train/RRc/chunk_0.record
# 2023-09-18 15:55:48.019205: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-09-18 15:55:48.019248: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: e1b09424bcd3
# 2023-09-18 15:55:48.019257: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: e1b09424bcd3
# 2023-09-18 15:55:48.019393: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: NOT_FOUND: was unable to find libcuda.so DSO loaded into this program
# 2023-09-18 15:55:48.019428: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 515.65.1
# 2023-09-18 15:55:48.019844: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Number of records within a class: RRab
#  - opening: data/records/alcock/fold_0/alcock_500/train/RRab/chunk_0.record
# Number of records within a class: Cep_1
#  - opening: data/records/alcock/fold_0/alcock_500/train/Cep_1/chunk_0.record
# Number of records within a class: Cep_0
#  - opening: data/records/alcock/fold_0/alcock_500/train/Cep_0/chunk_0.record
# Number of records within a class: LPV
#  - opening: data/records/alcock/fold_0/alcock_500/train/LPV/chunk_0.record
# Number of records within a class: EC
#  - opening: data/records/alcock/fold_0/alcock_500/train/EC/chunk_0.record
# Number of records within a class: RRc
#  - opening: data/records/alcock/fold_0/alcock_500/val/RRc/chunk_0.record
# Number of records within a class: RRab
#  - opening: data/records/alcock/fold_0/alcock_500/val/RRab/chunk_0.record
# Number of records within a class: Cep_1
#  - opening: data/records/alcock/fold_0/alcock_500/val/Cep_1/chunk_0.record
# Number of records within a class: Cep_0
#  - opening: data/records/alcock/fold_0/alcock_500/val/Cep_0/chunk_0.record
# Number of records within a class: LPV
#  - opening: data/records/alcock/fold_0/alcock_500/val/LPV/chunk_0.record
# Number of records within a class: EC
#  - opening: data/records/alcock/fold_0/alcock_500/val/EC/chunk_0.record
# Number of records within a class: RRc
#  - opening: data/records/alcock/fold_0/alcock_500/test/RRc/chunk_0.record
# Number of records within a class: RRab
#  - opening: data/records/alcock/fold_0/alcock_500/test/RRab/chunk_0.record
# Number of records within a class: Cep_1
#  - opening: data/records/alcock/fold_0/alcock_500/test/Cep_1/chunk_0.record
# Number of records within a class: Cep_0
#  - opening: data/records/alcock/fold_0/alcock_500/test/Cep_0/chunk_0.record
# Number of records within a class: LPV
#  - opening: data/records/alcock/fold_0/alcock_500/test/LPV/chunk_0.record
# Number of records within a class: EC
#  - opening: data/records/alcock/fold_0/alcock_500/test/EC/chunk_0.record
# Number of records within a class: DB
#  - opening: data/records/atlas/fold_0/atlas_500/train/DB/chunk_0.record
# Number of records within a class: Mira
#  - opening: data/records/atlas/fold_0/atlas_500/train/Mira/chunk_0.record
# Number of records within a class: Other
#  - opening: data/records/atlas/fold_0/atlas_500/train/Other/chunk_0.record
# Number of records within a class: Pulse
#  - opening: data/records/atlas/fold_0/atlas_500/train/Pulse/chunk_0.record
# Number of records within a class: CB
#  - opening: data/records/atlas/fold_0/atlas_500/train/CB/chunk_0.record
# Number of records within a class: DB
#  - opening: data/records/atlas/fold_0/atlas_500/val/DB/chunk_0.record
# Number of records within a class: Mira
#  - opening: data/records/atlas/fold_0/atlas_500/val/Mira/chunk_0.record
# Number of records within a class: Other
#  - opening: data/records/atlas/fold_0/atlas_500/val/Other/chunk_0.record
# Number of records within a class: Pulse
#  - opening: data/records/atlas/fold_0/atlas_500/val/Pulse/chunk_0.record
# Number of records within a class: CB
#  - opening: data/records/atlas/fold_0/atlas_500/val/CB/chunk_0.record
# Number of records within a class: DB
#  - opening: data/records/atlas/fold_0/atlas_500/test/DB/chunk_0.record
# Number of records within a class: Mira
#  - opening: data/records/atlas/fold_0/atlas_500/test/Mira/chunk_0.record
# Number of records within a class: Other
#  - opening: data/records/atlas/fold_0/atlas_500/test/Other/chunk_0.record
# Number of records within a class: Pulse
#  - opening: data/records/atlas/fold_0/atlas_500/test/Pulse/chunk_0.record
# Number of records within a class: CB
#  - opening: data/records/atlas/fold_0/atlas_500/test/CB/chunk_0.record
# Number of records within a class: ESD
#  - opening: data/records/ogle/fold_0/ogle_500/train/ESD/chunk_0.record
# Number of records within a class: OSARG
#  - opening: data/records/ogle/fold_0/ogle_500/train/OSARG/chunk_0.record
# Number of records within a class: ED
#  - opening: data/records/ogle/fold_0/ogle_500/train/ED/chunk_0.record
# Number of records within a class: SRV
#  - opening: data/records/ogle/fold_0/ogle_500/train/SRV/chunk_0.record
# Number of records within a class: cep
#  - opening: data/records/ogle/fold_0/ogle_500/train/cep/chunk_0.record
# Number of records within a class: RRc
#  - opening: data/records/ogle/fold_0/ogle_500/train/RRc/chunk_0.record
# Number of records within a class: RRab
#  - opening: data/records/ogle/fold_0/ogle_500/train/RRab/chunk_0.record
# Number of records within a class: Mira
#  - opening: data/records/ogle/fold_0/ogle_500/train/Mira/chunk_0.record
# Number of records within a class: EC
#  - opening: data/records/ogle/fold_0/ogle_500/train/EC/chunk_0.record
# Number of records within a class: dsct
#  - opening: data/records/ogle/fold_0/ogle_500/train/dsct/chunk_0.record
# Number of records within a class: ESD
#  - opening: data/records/ogle/fold_0/ogle_500/val/ESD/chunk_0.record
# Number of records within a class: OSARG
#  - opening: data/records/ogle/fold_0/ogle_500/val/OSARG/chunk_0.record
# Number of records within a class: ED
#  - opening: data/records/ogle/fold_0/ogle_500/val/ED/chunk_0.record
# Number of records within a class: SRV
#  - opening: data/records/ogle/fold_0/ogle_500/val/SRV/chunk_0.record
# Number of records within a class: cep
#  - opening: data/records/ogle/fold_0/ogle_500/val/cep/chunk_0.record
# Number of records within a class: RRc
#  - opening: data/records/ogle/fold_0/ogle_500/val/RRc/chunk_0.record
# Number of records within a class: RRab
#  - opening: data/records/ogle/fold_0/ogle_500/val/RRab/chunk_0.record
# Number of records within a class: Mira
#  - opening: data/records/ogle/fold_0/ogle_500/val/Mira/chunk_0.record
# Number of records within a class: EC
#  - opening: data/records/ogle/fold_0/ogle_500/val/EC/chunk_0.record
# Number of records within a class: dsct
#  - opening: data/records/ogle/fold_0/ogle_500/val/dsct/chunk_0.record
# Number of records within a class: ESD
#  - opening: data/records/ogle/fold_0/ogle_500/test/ESD/chunk_0.record
# Number of records within a class: OSARG
#  - opening: data/records/ogle/fold_0/ogle_500/test/OSARG/chunk_0.record
# Number of records within a class: ED
#  - opening: data/records/ogle/fold_0/ogle_500/test/ED/chunk_0.record
# Number of records within a class: SRV
#  - opening: data/records/ogle/fold_0/ogle_500/test/SRV/chunk_0.record
# Number of records within a class: cep
#  - opening: data/records/ogle/fold_0/ogle_500/test/cep/chunk_0.record
# Number of records within a class: RRc
#  - opening: data/records/ogle/fold_0/ogle_500/test/RRc/chunk_0.record
# Number of records within a class: RRab
#  - opening: data/records/ogle/fold_0/ogle_500/test/RRab/chunk_0.record
# Number of records within a class: Mira
#  - opening: data/records/ogle/fold_0/ogle_500/test/Mira/chunk_0.record
# Number of records within a class: EC
#  - opening: data/records/ogle/fold_0/ogle_500/test/EC/chunk_0.record
# Number of records within a class: dsct
#  - opening: data/records/ogle/fold_0/ogle_500/test/dsct/chunk_0.record
# Number of records within a class: D
#  - opening: data/records/kepler/fold_0/kepler/train/D/chunk_0.record
# Number of records within a class: SD
#  - opening: data/records/kepler/fold_0/kepler/train/SD/chunk_0.record
# Number of records within a class: ELV
#  - opening: data/records/kepler/fold_0/kepler/train/ELV/chunk_0.record
# Number of records within a class: OC
#  - opening: data/records/kepler/fold_0/kepler/train/OC/chunk_0.record
# Number of records within a class: D
#  - opening: data/records/kepler/fold_0/kepler/val/D/chunk_0.record
# Number of records within a class: SD
#  - opening: data/records/kepler/fold_0/kepler/val/SD/chunk_0.record
# Number of records within a class: ELV
#  - opening: data/records/kepler/fold_0/kepler/val/ELV/chunk_0.record
# Number of records within a class: OC
#  - opening: data/records/kepler/fold_0/kepler/val/OC/chunk_0.record
# Number of records within a class: D
#  - opening: data/records/kepler/fold_0/kepler/test/D/chunk_0.record
# Number of records within a class: SD
#  - opening: data/records/kepler/fold_0/kepler/test/SD/chunk_0.record
# Number of records within a class: ELV
#  - opening: data/records/kepler/fold_0/kepler/test/ELV/chunk_0.record
# Number of records within a class: OC
#  - opening: data/records/kepler/fold_0/kepler/test/OC/chunk_0.record
# Number of records within a class: D
#  - opening: data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/train/D/chunk_0.record
# Number of records within a class: SD
#  - opening: data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/train/SD/chunk_0.record
# Number of records within a class: ELV
#  - opening: data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/train/ELV/chunk_0.record
# Number of records within a class: OC
#  - opening: data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/train/OC/chunk_0.record
# Number of records within a class: D
#  - opening: data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/val/D/chunk_0.record
# Number of records within a class: SD
#  - opening: data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/val/SD/chunk_0.record
# Number of records within a class: ELV
#  - opening: data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/val/ELV/chunk_0.record
# Number of records within a class: OC
#  - opening: data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/val/OC/chunk_0.record
# Number of records within a class: D
#  - opening: data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/test/D/chunk_0.record
# Number of records within a class: SD
#  - opening: data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/test/SD/chunk_0.record
# Number of records within a class: ELV
#  - opening: data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/test/ELV/chunk_0.record
# Number of records within a class: OC
#  - opening: data/records/kepler_alcock_cubic/fold_0/kepler_alcock_cubic/test/OC/chunk_0.record
# Number of records within a class: D
#  - opening: data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/train/D/chunk_0.record
# Number of records within a class: SD
#  - opening: data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/train/SD/chunk_0.record
# Number of records within a class: ELV
#  - opening: data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/train/ELV/chunk_0.record
# Number of records within a class: OC
#  - opening: data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/train/OC/chunk_0.record
# Number of records within a class: D
#  - opening: data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/val/D/chunk_0.record
# Number of records within a class: SD
#  - opening: data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/val/SD/chunk_0.record
# Number of records within a class: ELV
#  - opening: data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/val/ELV/chunk_0.record
# Number of records within a class: OC
#  - opening: data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/val/OC/chunk_0.record
# Number of records within a class: D
#  - opening: data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/test/D/chunk_0.record
# Number of records within a class: SD
#  - opening: data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/test/SD/chunk_0.record
# Number of records within a class: ELV
#  - opening: data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/test/ELV/chunk_0.record
# Number of records within a class: OC
#  - opening: data/records/kepler_atlas_cubic/fold_0/kepler_atlas_cubic/test/OC/chunk_0.record
# Number of records within a class: D
#  - opening: data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/train/D/chunk_0.record
# Number of records within a class: SD
#  - opening: data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/train/SD/chunk_0.record
# Number of records within a class: ELV
#  - opening: data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/train/ELV/chunk_0.record
# Number of records within a class: OC
#  - opening: data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/train/OC/chunk_0.record
# Number of records within a class: D
#  - opening: data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/val/D/chunk_0.record
# Number of records within a class: SD
#  - opening: data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/val/SD/chunk_0.record
# Number of records within a class: ELV
#  - opening: data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/val/ELV/chunk_0.record
# Number of records within a class: OC
#  - opening: data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/val/OC/chunk_0.record
# Number of records within a class: D
#  - opening: data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/test/D/chunk_0.record
# Number of records within a class: SD
#  - opening: data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/test/SD/chunk_0.record
# Number of records within a class: ELV
#  - opening: data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/test/ELV/chunk_0.record
# Number of records within a class: OC
#  - opening: data/records/kepler_ogle_cubic/fold_0/kepler_ogle_cubic/test/OC/chunk_0.record

# %%
### ------------------------------------------------------------------------ ###
# ALCOCK
print('Training distribution')
train_mag_lcs_alcock, train_cadence_alcock = distribution_values(train_alcock)
print('Validation distribution')
val_mag_lcs_alcock, val_cadence_alcock = distribution_values(val_alcock)
print('Test distribution')
test_mag_lcs_alcock, test_cadence_alcock = distribution_values(test_alcock)

# ATLAS
print('Training distribution')
train_mag_lcs_atlas, train_cadence_atlas = distribution_values(train_atlas)
print('Validation distribution')
val_mag_lcs_atlas, val_cadence_atlas = distribution_values(val_atlas)
print('Test distribution')
test_mag_lcs_atlas, test_cadence_atlas = distribution_values(test_atlas)

# OGLE
print('Training distribution')
train_mag_lcs_ogle, train_cadence_ogle = distribution_values(train_ogle)
print('Validation distribution')
val_mag_lcs_ogle, val_cadence_ogle = distribution_values(val_ogle)
print('Test distribution')
test_mag_lcs_ogle, test_cadence_ogle = distribution_values(test_ogle)

### ------------------------------------------------------------------------ ###

## ALCOCK-ATLAS
#print('Training distribution')
#train_mag_lcs_alcock_atlas, train_cadence_alcock_atlas = distribution_values(train_alcock_atlas)
#print('Validation distribution')
#val_mag_lcs_alcock_atlas, val_cadence_alcock_atlas = distribution_values(val_alcock_atlas)
#print('Test distribution')
#test_mag_lcs_alcock_atlas, test_cadence_alcock_atlas = distribution_values(test_alcock_atlas)
#
## ALCOCK-OGLE
#print('Training distribution')
#train_mag_lcs_alcock_ogle, train_cadence_alcock_ogle = distribution_values(train_alcock_ogle)
#print('Validation distribution')
#val_mag_lcs_alcock_ogle, val_cadence_alcock_ogle = distribution_values(val_alcock_ogle)
#print('Test distribution')
#test_mag_lcs_alcock_ogle, test_cadence_alcock_ogle = distribution_values(test_alcock_ogle)

### ------------------------------------------------------------------------ ###

# KEPLER
print('Training distribution')
train_mag_lcs_kepler, train_cadence_kepler = distribution_values(train_kepler)
print('Validation distribution')
val_mag_lcs_kepler, val_cadence_kepler = distribution_values(val_kepler)
print('Test distribution')
test_mag_lcs_kepler, test_cadence_kepler = distribution_values(test_kepler)

# KEPLER-ALCOCK
print('Training distribution')
train_mag_lcs_kepler_alcock, train_cadence_kepler_alcock = distribution_values(train_kepler_alcock_cubic)
print('Validation distribution')
val_mag_lcs_kepler_alcock, val_cadence_kepler_alcock = distribution_values(val_kepler_alcock_cubic)
print('Test distribution')
test_mag_lcs_kepler_alcock, test_cadence_kepler_alcock = distribution_values(test_kepler_alcock_cubic)

# KEPLER-ATLAS
print('Training distribution')
train_mag_lcs_kepler_atlas, train_cadence_kepler_atlas = distribution_values(train_kepler_atlas_cubic)
print('Validation distribution')
val_mag_lcs_kepler_atlas, val_cadence_kepler_atlas = distribution_values(val_kepler_atlas_cubic)
print('Test distribution')
test_mag_lcs_kepler_atlas, test_cadence_kepler_atlas = distribution_values(test_kepler_atlas_cubic)

# KEPLER-OGLE
print('Training distribution')
train_mag_lcs_kepler_ogle, train_cadence_kepler_ogle = distribution_values(train_kepler_ogle_cubic)
print('Validation distribution')
val_mag_lcs_kepler_ogle, val_cadence_kepler_ogle = distribution_values(val_kepler_ogle_cubic)
print('Test distribution')
test_mag_lcs_kepler_ogle, test_cadence_kepler_ogle = distribution_values(test_kepler_ogle_cubic)

### ------------------------------------------------------------------------ ###
# Out:
# Training distribution
# /home/users/dmoreno2016/codes_implemented/utils.py:52: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.concatenate(np.array(mag_lcs)), np.concatenate(np.array(mjd_lcs_diff))
# Validation distribution
# Test distribution
# Training distribution
# Validation distribution
# Test distribution
# Training distribution
# Validation distribution
# Test distribution
# Training distribution
# Validation distribution
# Test distribution
# Training distribution
# Validation distribution
# Test distribution
# Training distribution
# Validation distribution
# Test distribution
# Training distribution
# Validation distribution
# Test distribution

# %%
alcock_cadence_subsets = [train_cadence_alcock, val_cadence_alcock, test_cadence_alcock]
atlas_cadence_subsets = [train_cadence_atlas, val_cadence_atlas, test_cadence_atlas]
ogle_cadence_subsets = [train_cadence_ogle, val_cadence_ogle, test_cadence_ogle]

#alcock_atlas_cadence_subsets = [train_cadence_alcock_atlas, val_cadence_alcock_atlas, test_cadence_alcock_atlas]
#alcock_ogle_cadence_subsets = [train_cadence_alcock_ogle, val_cadence_alcock_ogle, test_cadence_alcock_ogle]

kepler_cadence_subsets = [train_cadence_kepler, val_cadence_kepler, test_cadence_kepler]
kepler_alcock_cadence_subsets = [train_cadence_kepler_alcock, val_cadence_kepler_alcock, test_cadence_kepler_alcock]
kepler_atlas_cadence_subsets = [train_cadence_kepler_atlas, val_cadence_kepler_atlas, test_cadence_kepler_atlas]
kepler_ogle_cadence_subsets = [train_cadence_kepler_ogle, val_cadence_kepler_ogle, test_cadence_kepler_ogle]

# %%
alcock_cadence_dataset = create_df_dataset(alcock_cadence_subsets, name_col='cadence')
atlas_cadence_dataset = create_df_dataset(atlas_cadence_subsets, name_col='cadence')
ogle_cadence_dataset = create_df_dataset(ogle_cadence_subsets, name_col='cadence')

#alcock_atlas_cadence_dataset = create_df_dataset(alcock_atlas_cadence_subsets, name_col='cadence')
#alcock_ogle_cadence_dataset = create_df_dataset(alcock_ogle_cadence_subsets, name_col='cadence')

kepler_cadence_dataset = create_df_dataset(kepler_cadence_subsets, name_col='cadence')
kepler_alcock_cadence_dataset = create_df_dataset(kepler_alcock_cadence_subsets, name_col='cadence')
kepler_atlas_cadence_dataset = create_df_dataset(kepler_atlas_cadence_subsets, name_col='cadence')
kepler_ogle_cadence_dataset = create_df_dataset(kepler_ogle_cadence_subsets, name_col='cadence')

# %%
X_alcock = alcock_cadence_dataset['cadence'].values
X_atlas = atlas_cadence_dataset['cadence'].values
X_ogle = ogle_cadence_dataset['cadence'].values

print(X_alcock.shape)
print(X_atlas.shape)
print(X_ogle.shape)

print('*'*30)

#X_alcock_atlas = alcock_atlas_cadence_dataset['cadence'].values
#X_alcock_ogle = alcock_ogle_cadence_dataset['cadence'].values
#
#print(X_alcock_atlas.shape)
#print(X_alcock_ogle.shape)

print('*'*30)

X_kepler = kepler_cadence_dataset['cadence'].values
X_kepler_alcock = kepler_alcock_cadence_dataset['cadence'].values
X_kepler_atlas = kepler_atlas_cadence_dataset['cadence'].values
X_kepler_ogle = kepler_ogle_cadence_dataset['cadence'].values

print(X_kepler.shape)
print(X_kepler_alcock.shape)
print(X_kepler_atlas.shape)
print(X_kepler_ogle.shape)
# Out:
# (2506759,)
# (375084,)
# (4698161,)
# ******************************
# ******************************
# (118653545,)
# (696978,)
# (609197,)
# (768147,)

# %%
print('**************** ALCOCK dataset ****************')
print('Mediana: {:.3f}'.format(np.median(X_alcock)))
print('Media: {:.3f}'.format(np.mean(X_alcock)))
print('Std: {:.3f}'.format(np.std(X_alcock)))
print('Min: {:.3f}'.format(np.min(X_alcock)))
print('Max: {:.3f}'.format(np.max(X_alcock)))

print('**************** ATLAS dataset ****************')
print('Mediana: {:.3f}'.format(np.median(X_atlas)))
print('Media: {:.3f}'.format(np.mean(X_atlas)))
print('Std: {:.3f}'.format(np.std(X_atlas)))
print('Min: {:.3f}'.format(np.min(X_atlas)))
print('Max: {:.3f}'.format(np.max(X_atlas)))

print('**************** OGLE dataset ****************')
print('Mediana: {:.3f}'.format(np.median(X_ogle)))
print('Media: {:.3f}'.format(np.mean(X_ogle)))
print('Std: {:.3f}'.format(np.std(X_ogle)))
print('Min: {:.3f}'.format(np.min(X_ogle)))
print('Max: {:.3f}'.format(np.max(X_ogle)))

#print('**************** ALCOCK_ATLAS dataset ****************')
#print('Mediana: {:.3f}'.format(np.median(X_alcock_atlas)))
#print('Media: {:.3f}'.format(np.mean(X_alcock_atlas)))
#print('Std: {:.3f}'.format(np.std(X_alcock_atlas)))
#
#print('**************** ALCOCK_OGLE dataset ****************')
#print('Mediana: {:.3f}'.format(np.median(X_alcock_ogle)))
#print('Media: {:.3f}'.format(np.mean(X_alcock_ogle)))
#print('Std: {:.3f}'.format(np.std(X_alcock_ogle)))

print('**************** KEPLER dataset ****************')
print('Mediana: {:.3f}'.format(np.median(X_kepler)))
print('Media: {:.3f}'.format(np.mean(X_kepler)))
print('Std: {:.3f}'.format(np.std(X_kepler)))

print('**************** KEPLER_ALCOCK dataset ****************')
print('Mediana: {:.3f}'.format(np.median(X_kepler_alcock)))
print('Media: {:.3f}'.format(np.mean(X_kepler_alcock)))
print('Std: {:.3f}'.format(np.std(X_kepler_alcock)))

print('**************** KEPLER_ATLAS dataset ****************')
print('Mediana: {:.3f}'.format(np.median(X_kepler_atlas)))
print('Media: {:.3f}'.format(np.mean(X_kepler_atlas)))
print('Std: {:.3f}'.format(np.std(X_kepler_atlas)))

print('**************** KEPLER_OGLE dataset ****************')
print('Mediana: {:.3f}'.format(np.median(X_kepler_ogle)))
print('Media: {:.3f}'.format(np.mean(X_kepler_ogle)))
print('Std: {:.3f}'.format(np.std(X_kepler_ogle)))
# Out:
# **************** ALCOCK dataset ****************
# Mediana: 1.930
# Media: 3.827
# Std: 10.607
# Min: 0.000
# Max: 1533.992
# **************** ATLAS dataset ****************
# Mediana: 0.016
# Media: 4.864
# Std: 19.766
# Min: 0.000
# Max: 621.230
# **************** OGLE dataset ****************
# Mediana: 1.094
# Media: 3.492
# Std: 14.510
# Min: 0.001
# Max: 2156.921
# **************** KEPLER dataset ****************
# Mediana: 0.020
# Media: 0.024
# Std: 0.510
# **************** KEPLER_ALCOCK dataset ****************
# Mediana: 2.066
# Media: 4.098
# Std: 9.873
# **************** KEPLER_ATLAS dataset ****************
# Mediana: 0.113
# Media: 4.607
# Std: 18.394
# **************** KEPLER_OGLE dataset ****************
# Mediana: 1.531
# Media: 3.696
# Std: 12.760

# %%
import matplotlib.lines as mlines

fig, axes = plt.subplots(2, 2, figsize=(11, 7), sharey=True, sharex=True)
#fig.suptitle('Cadence distribution', x=0.52, size=17)

aux_bins = np.array([[200, 200],
                     [200, 200]])
bins = np.array([[1900, 450],
                 [250, 150]])
bins += aux_bins
name_datasets = [['OGLE', 'ATLAS'],
                 ['ALCOCK with OGLE cadence', 'ALCOCK with ATLAS cadence']]
datasets = [[ogle_cadence_dataset, atlas_cadence_dataset],
            [alcock_ogle_cadence_dataset, alcock_atlas_cadence_dataset]]

inf_xlim = -5
sup_xlim = 50

for col, col_datasets in enumerate(zip(bins, name_datasets, datasets)):
    for row, row_dataset in enumerate(zip(col_datasets[0], col_datasets[1], col_datasets[2])):
        # ALCOCK
        axes[row][col].hist(row_dataset[2]['cadence'], density=True, bins=row_dataset[0], color='#377eb8')
        axes[row][col].set_title(row_dataset[1], fontsize=12, pad=12)

        avg = np.average(row_dataset[2]['cadence'])
        median = np.median(row_dataset[2]['cadence'])
        std = np.std(row_dataset[2]['cadence'])
        max_value = np.max(row_dataset[2]['cadence'])
        min_value = np.min(row_dataset[2]['cadence'])
        
        axes[row][col].axvline(median, linestyle='dashdot', color='#e41a1c', label=f'Median = {median: .2f}')
        axes[row][col].axvline(avg, linestyle='--', color='k', label=f'Average = {avg: .2f}')
        axes[row][col].axvline(avg - std, linestyle=':', color='k', label=f'Stdev = {std: .2f}')
        axes[row][col].axvline(avg + std, linestyle=':', color='k')

        handles, labels = axes[row][col].get_legend_handles_labels()
        point_max = mlines.Line2D([0], [0], marker='o', color='w', label=f'Max = {max_value: .2f}',
                                  markerfacecolor='black', markersize=4, ls = '')
        handles.extend([point_max])
        axes[row][col].legend(handles=handles, fontsize=13)
        
        if col == 0:
            axes[row][col].set_ylabel('Density', fontsize=14, labelpad=11) # Y label

        if row == len(datasets[0])-1:
            axes[row][col].set_xlabel(r'Mean $\Delta$Time [days]', fontsize=14, labelpad=11) # X label 
        
        axes[row][col].tick_params(axis='both', labelsize=14)

        axes[row][col].set_xlim([inf_xlim, sup_xlim])
    
plt.tight_layout()
#plt.savefig('./Analysis_data/Cadence_distribution_PAPER_data.png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.lines as mlines

fig, axes = plt.subplots(2, 3, figsize=(15, 7), sharey=True, sharex=True)
#fig.suptitle('Cadence distribution', x=0.52, size=17)

aux_bins = np.array([[200, 180],
                     [200, 200],
                     [200, 200]])
bins = np.array([[700, 15],
                 [1900, 10],
                 [150, 10]])
bins += aux_bins
name_datasets = [['ALCOCK', 'KEPLER with ALCOCK cadence'],
                 ['OGLE', 'KEPLER with OGLE cadence'],
                 ['ATLAS', 'KEPLER with ATLAS cadence']]
datasets = [[alcock_cadence_dataset, kepler_alcock_cadence_dataset],
            [ogle_cadence_dataset, kepler_ogle_cadence_dataset],
            [atlas_cadence_dataset, kepler_atlas_cadence_dataset]]

inf_xlim = -5
sup_xlim = 50

for col, col_datasets in enumerate(zip(bins, name_datasets, datasets)):
    for row, row_dataset in enumerate(zip(col_datasets[0], col_datasets[1], col_datasets[2])):
        # ALCOCK
        axes[row][col].hist(row_dataset[2]['cadence'], density=True, bins=row_dataset[0], color='#377eb8')
        axes[row][col].set_title(row_dataset[1], fontsize=12, pad=12)

        avg = np.average(row_dataset[2]['cadence'])
        median = np.median(row_dataset[2]['cadence'])
        std = np.std(row_dataset[2]['cadence'])
        max_value = np.max(row_dataset[2]['cadence'])
        min_value = np.min(row_dataset[2]['cadence'])
        
        axes[row][col].axvline(median, linestyle='dashdot', color='#e41a1c', label=f'Median = {median: .2f}')
        axes[row][col].axvline(avg, linestyle='--', color='k', label=f'Average = {avg: .2f}')
        axes[row][col].axvline(avg - std, linestyle=':', color='k', label=f'Stdev = {std: .2f}')
        axes[row][col].axvline(avg + std, linestyle=':', color='k')

        handles, labels = axes[row][col].get_legend_handles_labels()
        point_max = mlines.Line2D([0], [0], marker='o', color='w', label=f'Max = {max_value: .2f}',
                                  markerfacecolor='black', markersize=4, ls = '')
        handles.extend([point_max])
        axes[row][col].legend(handles=handles, fontsize=13)
        
        if col == 0:
            axes[row][col].set_ylabel('Density', fontsize=14, labelpad=11) # Y label

        if row == len(datasets[0])-1:
            axes[row][col].set_xlabel(r'Mean $\Delta$Time [days]', fontsize=14, labelpad=11) # X label 
        
        axes[row][col].tick_params(axis='both', labelsize=14)

        axes[row][col].set_xlim([inf_xlim, sup_xlim])
    
plt.tight_layout()
#plt.savefig('./Analysis_data/Cadence_distribution_PAPER_data.png', bbox_inches='tight')
plt.show()

# %%
alcock_mag_lcs_subsets = [train_mag_lcs_alcock, val_mag_lcs_alcock, test_mag_lcs_alcock]
alcock_atlas_mag_lcs_subsets = [train_mag_lcs_alcock_atlas, val_mag_lcs_alcock_atlas, test_mag_lcs_alcock_atlas]
alcock_ogle_mag_lcs_subsets = [train_mag_lcs_alcock_ogle, val_mag_lcs_alcock_ogle, test_mag_lcs_alcock_ogle]

alcock_mag_lcs_dataset = create_df_dataset(alcock_mag_lcs_subsets, name_col='Magnitude')
alcock_atlas_mag_lcs_dataset = create_df_dataset(alcock_atlas_mag_lcs_subsets, name_col='Magnitude')
alcock_ogle_mag_lcs_dataset = create_df_dataset(alcock_ogle_mag_lcs_subsets, name_col='Magnitude')

# %%
fig, axes = plt.subplots(2, 2, figsize=(11, 7), sharey=True, sharex=True)
#fig.suptitle('Flux distribution', x=0.53, size=17)

name_datasets = [['ALCOCK with ATLAS cadence', 'ALCOCK with OGLE cadence'],
                 ['ALCOCK']]
datasets = [[alcock_atlas_mag_lcs_dataset, alcock_ogle_mag_lcs_dataset],
            [alcock_mag_lcs_dataset]]

inf_xlim = -26
sup_xlim = 25
                 
for col, col_datasets in enumerate(zip(name_datasets, datasets)):
    for row, row_dataset in enumerate(zip(col_datasets[0], col_datasets[1])):
        # DATASET
        sns.kdeplot(data=row_dataset[1], x="Magnitude", ax=axes[row][col], color='#377eb8')
        axes[row][col].set(xlabel=None)

        axes[row][col].set_title(row_dataset[0], fontsize=12, pad=12)

        avg = np.average(row_dataset[1]['Magnitude'])
        std = np.std(row_dataset[1]['Magnitude'])
        axes[row][col].axvline(avg, linestyle='--', color='k', label=f'Average = {avg: .5f}')
        axes[row][col].axvline(avg - std, linestyle=':', color='k', label=f'Stdev = {std: .5f}')
        axes[row][col].axvline(avg + std, linestyle=':', color='k')
        axes[row][col].legend(fontsize=13)

        axes[row][col].set_xlim([inf_xlim, sup_xlim])
        axes[row][col].set_xlim([inf_xlim, sup_xlim])
        axes[row][col].set_xlim([inf_xlim, sup_xlim])
        
        axes[row][col].set_ylabel('Density', fontsize=14, labelpad=11) # Y label
        axes[row][col].set_xlabel('Magnitude', fontsize=14, labelpad=11) # X label
        
        axes[row][col].tick_params(axis='both', labelsize=12)

plt.tight_layout()
#plt.savefig('./Analysis_data/Magnitude_distribution_PAPER_data.png', bbox_inches='tight')
plt.show()

# %%
kepler_mag_lcs_subsets = [train_mag_lcs_kepler, val_mag_lcs_kepler, test_mag_lcs_kepler]
kepler_alcock_mag_lcs_subsets = [train_mag_lcs_kepler_alcock, val_mag_lcs_kepler_alcock, test_mag_lcs_kepler_alcock]
kepler_atlas_mag_lcs_subsets = [train_mag_lcs_kepler_atlas, val_mag_lcs_kepler_atlas, test_mag_lcs_kepler_atlas]
kepler_ogle_mag_lcs_subsets = [train_mag_lcs_kepler_ogle, val_mag_lcs_kepler_ogle, test_mag_lcs_kepler_ogle]

kepler_mag_lcs_dataset = create_df_dataset(kepler_mag_lcs_subsets, name_col='Magnitude')
kepler_alcock_mag_lcs_dataset = create_df_dataset(kepler_alcock_mag_lcs_subsets, name_col='Magnitude')
kepler_atlas_mag_lcs_dataset = create_df_dataset(kepler_atlas_mag_lcs_subsets, name_col='Magnitude')
kepler_ogle_mag_lcs_dataset = create_df_dataset(kepler_ogle_mag_lcs_subsets, name_col='Magnitude')

# %%
fig, axes = plt.subplots(2, 2, figsize=(11, 7), sharey=True, sharex=True)
#fig.suptitle('Flux distribution', x=0.53, size=17)

name_datasets = [['KEPLER cadence', 'KEPLER with ALCOCK cadence'],
                 ['KEPLER with OGLE cadence', 'KEPLER with ATLAS cadence']]
datasets = [[kepler_mag_lcs_dataset, kepler_alcock_mag_lcs_dataset],
            [kepler_ogle_mag_lcs_dataset, kepler_atlas_mag_lcs_dataset]]

inf_xlim = -3.5
sup_xlim = 3.5
                 
for col, col_datasets in enumerate(zip(name_datasets, datasets)):
    for row, row_dataset in enumerate(zip(col_datasets[0], col_datasets[1])):
        # DATASET
        sns.kdeplot(data=row_dataset[1], x="Magnitude", ax=axes[row][col], color='#377eb8')
        axes[row][col].set(xlabel=None)

        axes[row][col].set_title(row_dataset[0], fontsize=12, pad=12)

        avg = np.average(row_dataset[1]['Magnitude'])
        std = np.std(row_dataset[1]['Magnitude'])
        axes[row][col].axvline(avg, linestyle='--', color='k', label=f'Average = {avg: .5f}')
        axes[row][col].axvline(avg - std, linestyle=':', color='k', label=f'Stdev = {std: .5f}')
        axes[row][col].axvline(avg + std, linestyle=':', color='k')
        axes[row][col].legend(fontsize=13)

        axes[row][col].set_xlim([inf_xlim, sup_xlim])
        axes[row][col].set_xlim([inf_xlim, sup_xlim])
        axes[row][col].set_xlim([inf_xlim, sup_xlim])
        
        axes[row][col].set_ylabel('Density', fontsize=14, labelpad=11) # Y label
        axes[row][col].set_xlabel('Magnitude', fontsize=14, labelpad=11) # X label
        
        axes[row][col].tick_params(axis='both', labelsize=12)

plt.tight_layout()
#plt.savefig('./Analysis_data/Magnitude_distribution_PAPER_data.png', bbox_inches='tight')
plt.show()
