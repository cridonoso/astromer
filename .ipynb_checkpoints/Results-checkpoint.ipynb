# %%
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import tensorflow as tf

from core.data import make_batches, positional_encoding, tokenizers
from core.transformer import Transformer, MiniTransformer
from core.scheduler import CustomSchedule
from core.callbacks import get_callbacks

# %%
# Hyperparameters
num_layers = 4
d_model = 128
dff = 512
num_heads = 8
dropout_rate = 0.1
exp_path = "./experiments/train"
EPOCHS = 20
BATCHSIZE = 64

# %%
examples, metadata = tfds.load('ted_hrlr_translate/pt_to_en', with_info=True,
                               as_supervised=True)
test_examples = examples['test']
test_batches = make_batches(test_examples, batchsize=BATCHSIZE)

# %%
# Optimizer
learning_rate = CustomSchedule(d_model)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# Loss Function
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, 
                                                            reduction='none')

transformer = MiniTransformer(num_layers=num_layers,
                              d_model=d_model,
                              num_heads=num_heads,
                              dff=dff,
                              input_vocab_size=tokenizers.pt.get_vocab_size(),
                              target_vocab_size=tokenizers.en.get_vocab_size(),
                              pe_input=1000,
                              rate=0.1)
transformer.compile(optimizer=optimizer, 
                    loss_function=loss_object,
                    metrics=['accuracy', loss_object])

transformer.model(BATCHSIZE)

transformer.evaluate(test_batches.take(1))
# Out:
# 1/1 [==============================] - 2s 2s/step - accuracy: 0.0000e+00 - sparse_categorical_crossentropy: 9.1995
# [0.0, 9.199488639831543]

# %%
expdir = '{}/train_model.h5'.format(exp_path)
transformer.load_weights(expdir)

# %%
prediction = transformer.predict(test_batches.take(1))

# %%
y_pred = prediction[0]
y_true = prediction[1]

# %%
for t, k in zip(y_pred, y_true):
    print(k.decode('utf-8'))
    print(t.decode('utf-8'))
    print('-'*10)
# Out:
# b"and maybe the hardest thing of all is to figure out that what other people think and feel is n ' t actually exactly like what we think and feel ."
# and i it problem thing that the ? , do out how the we people are of how that that ' t going going what . they ' . what .
# ----------
# b"that ' s what you should have said . right ? why is this ?"
# and ' s what we see do done . ? ? it ?
# ----------
# b'what we have here is one exploit file .'
# and i do to is that ofings
# ----------
# b"it ' s called a microscope ."
# and ' s a the p .
# ----------
# b'he had 498 people to prepare his dinner every night .'
# and ' to24 pounds in read to own for day .
# ----------
# b'translate that for me .'
# ands is a is
# ----------
# b'it is caused by prematurity and genetic conditions .'
# and ' a by actionrine and building variation .
# ----------
# b"it ' s for the number needed to treat ."
# and ' s a a first of . be the
# ----------
# b"bl : right ? so we ' ve got our observations . we ' ve got our data ."
# andoo : thank ? , ' re got to first . ' ve got to little .
# ----------
# b'think about how far we have come .'
# and about it it it are to to
# ----------
# b'there are some light sources .'
# and ' many of places that
# ----------
# b'they were always best in class .'
# and ' all the . the .
# ----------
# b"` ` so , if i say , ` ` ' ' freedom , sovereignty , independence ( english ) , ' ' ' ' or if your son came up to you and said , ` ` dad , have you lived through the period of the freedom ( english ) slogan ? ' ' ' '"
# and ` ` i i you ' , ` ` ' ' i , i ,eign . . ' , laughter ) ' ' ' ' ' and ` you name ' to with the , say , ` ` 'dy i you ' in the world of the world of laughter ) thewgant ' ' '
# ----------
# b"ag : okay , he ' s got his experimental notebook out ."
# and : so , so ' s going a own resultsbook . of
# ----------
# b'they made his silly outfits , like this , ( laughter ) and they did his silly hairstyles , or whatever .'
# and ' a own stuff ofs . and the , and laughter ) and they ' n job stuff . . to and they he
# ----------
# b'when i was in office as governor of georgia , one out of every 1 , 000 americans were in prison .'
# and you was a the , a inningr , aalopalia , i of of the morning , 000 , , in the .
# ----------
# b'love is powerful and at times painful , and we express this in our words and stories , but then our words and stories prime us to expect love to be powerful and painful .'
# and is a . powerful the . . but it are ourselves . a future of it . and we we ability are our ared . our the to be able . to .
# ----------
# b'so our metaphors equate the experience of loving someone to extreme violence or illness .'
# and i students is ofnuates time of theobin as ' see forms . not ,
# ----------
# b'that was the problem .'
# and ' the first .
# ----------
# b'( recording ) adam ostrow : hello .'
# and applause ) ( ,bslen thank .
# ----------
# b"they buy products on demand . a person in alex does n ' t buy a box of cigarettes . they buy one cigarette each day , even though it ' s more expensive ."
# and ' a . thes lot who thean n ' t have a piece . theheette . . ' a .hearette . other . and in it ' s a . .
# ----------
# b"the woman knows that , in the hadzas ' case here \xe2\x80\x94 digging roots to share with men in exchange for meat \xe2\x80\x94 she knows that all she has to do to get access to protein is to dig some extra roots and trade them for meat ."
# and world came that she when the next beenm , s , , the in and the the the ' the . their . and ' that the the is been be . be the to the and to theest of - of a center . the .
# ----------
# b'now i combine them with hi - tech materials and engineering to create voluptuous , billowing forms the scale of buildings .'
# and , ' a with ading based product . a and the aactort . - a gates and , . students of the .
# ----------
# b'they know .'
# and ' that
# ----------
# b"let ' s start from this moment ."
# and ' s take with the . .
# ----------
# b"but we wondered if there ' s a possible link with other animals . it ' d be amazing if humans and bees thought similar , since they seem so different from us ."
# and it ' if we was s a lot way to the people , ' s bes . you were it are , to if the ' to much . the .
# ----------
# b'about 20 days before the japanese earthquake happened , also they had a big earthquake , and many japanese students were also killed , and the most important cathedral of the city , the symbol of christchurch , was totally destroyed .'
# and a percent , i last i hit in i a had to little deal . and they of people would in a by and they first often speciess the world . and r of thetiingosi and the un .
# ----------
# b'we wanted to know if babies and young children could understand this really profound thing about other people .'
# and ' to do that we were people people were n their . different . . the people .
# ----------
# b"and more than that , it ' s a confection of different ideas , the idea of plastic , the idea of a laser , the idea of transistors ."
# and i importantly half , it ' s a littlenfr , the technology . and more is the , the other of thec only the only that theransgenorhip
# ----------
# b'hotel . . . bushmaster two - six , bushmaster two - six ,'
# and rwanda .y are . . americans percent andys . million year - and
# ----------
# b"do we get what ' s going to be now happening one day in the future ?"
# and you know to we s going on be ? ? ? of ? the world ?
# ----------
# b"oops , i ' m sorry . what was going on ?"
# andsy i ' m going . i the to ,
# ----------
# b"now there ' s a number of different rules the bees can learn to solve this puzzle . the interesting question is , which ?"
# and , ' s a lot of people ways . code in be to code the , . only things is , how is
# ----------
# b"and what ' s more , they felt that they should actually do things to help other people get what they wanted ."
# and i i s the is if ' like they could be do that like do them people . . they did to
# ----------
# b"avelile ' s mother had hiv virus \xe2\x80\x94 she died from aids - related illness ."
# and fewous of s energy came a / . a was in a , in diseases .
# ----------
# b'this issue was put on the political agenda by the uk prime minister david cameron at a big g8 summit that was held in northern ireland in 2013 .'
# and is is the a the internet table . the way . numberss mroomy theust pe . ofy was the the thent 'land . the years .
# ----------
# b'but what if you want to see brush strokes ?'
# and what i we could to do the thes like
# ----------
# b'nowadays , 7 . 3 people per 1 , 000 are in prison .'
# and , we , 3 million are year . 000 people going the .
# ----------
# b'voice : i think you got your birthday wish . mt : and that actually leaves me with the last , and most important card of all : the one with this very significant mark on it .'
# and : i ' that ' a attention . . : i i ' comes the with me rest course and i importantly things . the the the things that the . best challenge . the .
# ----------
# b'they put her on very special nutritious diet and took great care of her .'
# and ' the back her high side breakfast . attack the al as the to
# ----------
# b'now , you can imagine how much savings there would be for society .'
# and , i ' see that much money , . be a a ,
# ----------
# b'louis xiv had a lot of people working for him .'
# andoftsh the .k . to lot of money . on a to
# ----------
# b"if you had to start from scratch , let ' s say you go out into the countryside ."
# and you look a do to the , you ' s look , ' . . a video .s
# ----------
# b'what it allows you to do is see tiny little lifeforms that are invisible to the naked eye .'
# and i means you to do is to the little b ons , are the ecosystems the brain eye .
# ----------
# b"when did this happen ? we do n ' t know , but it ' s possible that neanderthals did n ' t do this ."
# and i you happen ? ' n ' t know . but we ' s a . the . n ' t have it .
# ----------
# b'dave strudwick : so you keep track of each . student : henry , can you help me here ?'
# androa :gyin , i i ' theed the other . i . i you read you ? ?
# ----------
# b'how did we achieve that ?'
# and do you get this ?
# ----------
# b'if we look at babies and young children , we see something very different .'
# and you can at the , animals people , we are the like similar .
# ----------
# b'so the whole is literally more than the sum of its parts .'
# and i problem thing the a than a last of the parts .
# ----------
# b'finally the priest , finally he trusted me to rebuild .'
# and , humanrot of the , wased the , work the
# ----------
# b"now play is not simply a process . experts in play will tell you that actually it ' s a way of being ."
# and , is a the a little of . the . . us about it is ' s not story . being a
# ----------
# b"now , at first , this was very difficult to believe , not least because the voices appeared so hostile and menacing , so in this respect , a vital first step was learning to separate out a metaphorical meaning from what i ' d previously interpreted to be a literal truth ."
# and , the the , the is a , to see in because to in it people were on muchile . started 'ly themselves but on the case . and lot role time of to . work the of lot . re that the was was m be beed . the . realer experience .
# ----------
# b'now in closing , i think what we all need to be thinking about is if we want that to become our reality \xe2\x80\x94 and if so , what it means for a definition of life and everything that comes after it .'
# and , this , i ' it i ' want to be , about this that we ' to we be a own . we what we , we we ' we us better of self , how else is to us '
# ----------
# b'now , you do get other animals working for each other too .'
# and , i know n a things . on a other . .
# ----------
# b"i ' m honored by the invitation , and thanks ."
# and ' m goinged . the mosts to and i to
# ----------
# b"it does n ' t work ."
# and ' n ' t matter .
# ----------
# b"now we ' re already seeing some services that are designed to let us decide what happens to our online profile and our social media accounts after we die ."
# and , ' re going going the of . are not to a us go to ' . us children nature . how students security . for a ' .
# ----------
# b'what first got me thinking about this was a blog post authored earlier this year by derek k . miller , who was a science and technology journalist who died of cancer .'
# and i means me thinking is this is that little , ,e of , year , aphmi ,il .ea a was a very fiction a .ic was . a .
# ----------
# b'well , it uses sexual reproduction .'
# and , it ' aitys to
# ----------
# b"is n ' t it extraordinary ?"
# and it ' t it ? ,
# ----------
# b'( laughter ) ag : now this is his next idea .'
# and applause ) and : i , is a name big .
# ----------
# b'everybody saw this makes a lot of sense .'
# and has the . me lot of money .
# ----------
# b'and yes , my sing campaign has supported treatment action campaign in the way that i have tried to raise awareness and to try to also raise funds .'
# and i , it wifeular is been me . . . the united it we was to to help your . how be to make understand your .
# ----------
# b"so half the time , she acted as if she liked the crackers and did n ' t like the broccoli \xe2\x80\x94 just like a baby and any other sane person ."
# and i of world , i 'ed up a she was to mother of , the n ' t have it sameoophrasmth she a , little ! a other day s . .
# ----------
